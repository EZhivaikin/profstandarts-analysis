# %%
import requests
import pprint
import pandas as pd
import asyncio
import aiohttp
import nest_asyncio
nest_asyncio.apply()

# %%
specializations = {
    'Администратор баз данных': {
        'specialization': '1.420', 
    },
    'Системный администратор информационно-коммуникационных систем': {
        'specialization': '25.383', 
    },
    
    'Программист': {
        'specialization': '1.221', 
    },
    
    'Специалист по тестированию в области информационных технологий': {
        'specialization': '1.117', 
    },
    
    'Специалист по информационным системам': {
        'specialization': '14.91', 
    },
    
    'Системный программист': {
       'specialization': ['1.272', '1.273'], 
    },
    
   'Специалист по администрированию сетевых устройств информационно-коммуникационных систем': {
       'specialization': '1.270',
       'text': 'администратор'
   },
    
    'Специалист по дизайну графических и пользовательских интерфейсов': {
        'text': 'дизайн интерфейсов',
    },
    
    'Системный аналитик': {
        'specialization': '1.25', 
    },
    
    'Руководитель проектов в области информационных технологий': {
        'specialization': '1.327', 
    },
    'Технический писатель': {
        'specialization': '1.296', 
    },
    'Архитектор программного обеспечения': {
        'text': 'System Architect'
    }
}

soft_skills = [
    ['Коммуникативные навыки', 'Информаирование сотрудников', 'Проведение собеседований', 'Проводить интервью', 'Проводить презентации', 'Консультирование', 'Обратная связь с заказчиком', 'Переговоры'],
    ['Работа в команде', 'Распределение задач', 'Командная работа'],
    ['Самоорганизация','Самообразование', 'Способность к непрерывному обучению', 'Самостоятельность', 'Структурировать собственные знания'],
    ['Критическое мышление','Аналитическое мышление','Системное мышление', 'Выбор стратегии', 'Выявление значимых характеристик', 'Анализ'],
    ['Планирование', 'Управление проектами','Распределение задач'],
    ['Межкультурное взаимодействие'],
    ['Эмоциональный интеллект', 'Эмпатия', 'Сопереживание'],
    ['Адаптивность', 'Работа в условиях неопределенности'],
    ['Организованность', 'Тайм-менеджмент'],
    ['Достижение результатов', 'Ответственность', 'Принятие риска', 'Инициативность', 'Настойчивость', 'Достижение целей', 'Распределение задач', 'Принятие решений'],
    ['Обучение других', 'Наставничество'],
    ['Разработка и реализация проектов', 'Распределение задач', 'Осуществление контроля', 'Коммуникации', 'Планирование']
]

test = ' OR '.join([f'"{x}"' for x in soft_skills[1]])

default_params = {
    'experience': 'between1And3',
    'per_page': 3,
    #'area': 1368,
    'page':0,
}
print(test)
# Out:
# "Работа в команде" OR "Распределение задач" OR "Командная работа"

# %%
r = requests.get('https://api.hh.ru/vacancies', params=default_params)
#r.json()

# %%
async def async_request(url, params):
    async with aiohttp.request(method='GET', url=url, params=params) as response:
        result = await response.json()
    return result

# %%
async def get_count_by_soft_skill(skill, params):
    synonyms = ' OR '.join([str(x) for x in skill])
    if params.get('text') is not None:
        synonyms = f'({synonyms}) AND {params.get("text")}'
    params.update({'text': synonyms})
    r = await async_request("https://api.hh.ru/vacancies", params)
    found_by_skill_number = r['found']
    return skill[0], found_by_skill_number

async def get_vacancies_number(profession):
    current_params = default_params.copy()
    current_params.update(specializations[profession])
    r = await async_request("https://api.hh.ru/vacancies", current_params)
    found_number = r['found']
    return profession, current_params, found_number
        
async def get_matrix():
    matrix = dict()
    futures = [get_vacancies_number(k) for k, _ in specializations.items()]
    for future in asyncio.as_completed(futures):
        profession, params, found_number = await future
        matrix[profession] = dict()
        matrix[profession]['Всего'] = found_number
        furure_skills = [get_count_by_soft_skill(skill, params.copy()) for skill in soft_skills]
        for future_skill in asyncio.as_completed(furure_skills):
            skill, found_by_skill_number = await future_skill
            matrix[profession][skill] = found_by_skill_number
    return matrix

ioloop = asyncio.get_event_loop()
skill_matrix = ioloop.run_until_complete(get_matrix())
#ioloop.close()

# %%
df = pd.DataFrame(skill_matrix)
df
# Out:
#                                   Специалист по информационным системам  \
# Всего                                                               750
# Межкультурное взаимодействие                                          0
# Обучение других                                                     129
# Работа в команде                                                    133
# Достижение результатов                                              166
# Разработка и реализация проектов                                    103
# Коммуникативные навыки                                              113
# Адаптивность                                                          8
# Эмоциональный интеллект                                               4
# Планирование                                                         56
# Самоорганизация                                                      49
# Критическое мышление                                                 88
# Организованность                                                     16
#
#                                   Администратор баз данных  \
# Всего                                                 2085
# Межкультурное взаимодействие                             0
# Обучение других                                        217
# Работа в команде                                       382
# Достижение результатов                                 588
# Разработка и реализация проектов                       326
# Коммуникативные навыки                                 406
# Адаптивность                                             8
# Эмоциональный интеллект                                 15
# Планирование                                           213
# Самоорганизация                                        227
# Критическое мышление                                   635
# Организованность                                        31
#
#                                   Специалист по тестированию в области информационных технологий  \
# Всего                                                                          3563
# Межкультурное взаимодействие                                                      0
# Обучение других                                                                 439
# Работа в команде                                                                834
# Достижение результатов                                                          994
# Разработка и реализация проектов                                                819
# Коммуникативные навыки                                                          734
# Адаптивность                                                                     30
# Эмоциональный интеллект                                                           3
# Планирование                                                                    590
# Самоорганизация                                                                 447
# Критическое мышление                                                           1557
# Организованность                                                                 40
#
#                                   Специалист по администрированию сетевых устройств информационно-коммуникационных систем  \
# Всего                                                                          1203
# Межкультурное взаимодействие                                                      0
# Обучение других                                                                  84
# Работа в команде                                                                142
# Достижение результатов                                                          322
# Разработка и реализация проектов                                                151
# Коммуникативные навыки                                                          172
# Адаптивность                                                                      3
# Эмоциональный интеллект                                                           0
# Планирование                                                                     98
# Самоорганизация                                                                 104
# Критическое мышление                                                            151
# Организованность                                                                 23
#
#                                   Специалист по дизайну графических и пользовательских интерфейсов  \
# Всего                                                                           809
# Межкультурное взаимодействие                                                      0
# Обучение других                                                                 103
# Работа в команде                                                                195
# Достижение результатов                                                          283
# Разработка и реализация проектов                                                218
# Коммуникативные навыки                                                           99
# Адаптивность                                                                     77
# Эмоциональный интеллект                                                           7
# Планирование                                                                    133
# Самоорганизация                                                                 132
# Критическое мышление                                                            181
# Организованность                                                                 14
#
#                                   Системный программист  Программист  \
# Всего                                              6912        15557
# Межкультурное взаимодействие                          0            0
# Обучение других                                     848         2010
# Работа в команде                                   1335         3550
# Достижение результатов                             2067         4108
# Разработка и реализация проектов                   1453         3419
# Коммуникативные навыки                             1627         2080
# Адаптивность                                         75          571
# Эмоциональный интеллект                              14           14
# Планирование                                       1030         2194
# Самоорганизация                                     865         1849
# Критическое мышление                               1814         3421
# Организованность                                    107          190
#
#                                   Системный аналитик  \
# Всего                                           4442
# Межкультурное взаимодействие                       0
# Обучение других                                  628
# Работа в команде                                 998
# Достижение результатов                          1474
# Разработка и реализация проектов                1476
# Коммуникативные навыки                          1241
# Адаптивность                                      34
# Эмоциональный интеллект                           16
# Планирование                                    1169
# Самоорганизация                                  658
# Критическое мышление                            3012
# Организованность                                 118
#
#                                   Архитектор программного обеспечения  \
# Всего                                                              84
# Межкультурное взаимодействие                                        0
# Обучение других                                                     5
# Работа в команде                                                   19
# Достижение результатов                                             24
# Разработка и реализация проектов                                   45
# Коммуникативные навыки                                             30
# Адаптивность                                                        0
# Эмоциональный интеллект                                             0
# Планирование                                                       20
# Самоорганизация                                                     7
# Критическое мышление                                               55
# Организованность                                                    1
#
#                                   Технический писатель  \
# Всего                                             1058
# Межкультурное взаимодействие                         0
# Обучение других                                    195
# Работа в команде                                   255
# Достижение результатов                             330
# Разработка и реализация проектов                   339
# Коммуникативные навыки                             284
# Адаптивность                                         6
# Эмоциональный интеллект                              3
# Планирование                                       240
# Самоорганизация                                    172
# Критическое мышление                               512
# Организованность                                    24
#
#                                   Руководитель проектов в области информационных технологий  \
# Всего                                                                          3928
# Межкультурное взаимодействие                                                      0
# Обучение других                                                                 600
# Работа в команде                                                               1079
# Достижение результатов                                                         1557
# Разработка и реализация проектов                                               1763
# Коммуникативные навыки                                                         1383
# Адаптивность                                                                     54
# Эмоциональный интеллект                                                          14
# Планирование                                                                   1858
# Самоорганизация                                                                 645
# Критическое мышление                                                           1632
# Организованность                                                                218
#
#                                   Системный администратор информационно-коммуникационных систем
# Всего                                                                           471
# Межкультурное взаимодействие                                                      0
# Обучение других                                                                  51
# Работа в команде                                                                 56
# Достижение результатов                                                          152
# Разработка и реализация проектов                                                 75
# Коммуникативные навыки                                                          100
# Адаптивность                                                                      0
# Эмоциональный интеллект                                                           0
# Планирование                                                                     36
# Самоорганизация                                                                  36
# Критическое мышление                                                             35
# Организованность                                                                  6

# %%
df.to_excel('prof_hmao.xlsx')
